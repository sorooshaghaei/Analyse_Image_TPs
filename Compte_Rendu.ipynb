# %% [markdown]
# # Compte Rendu de TP - Séance 5
#
# **Cours :** Analyse d'Image- Master 1 (second semestre)
# **Étudiant :** Mehdi AGHAEI
# **Date :** 8 fev 2026
# **Lien GitHub :** [https://github.com/sorooshaghaei/Analyse_Image_TPs](https://github.com/sorooshaghaei/Analyse_Image_TPs)
#
# ---
#
# ## 1. Introduction
#
# Ce rapport présente l'état d'avancement des travaux pratiques effectués jusqu'à la séance 5.
#
# ---
#
# ## 2. État d'Avancement
#
# ### TP1 : Prise en main et Dessin
#
# - **Statut :** Terminé.
# - **Réalisations :** Manipulation des matrices, dessin de formes géométriques (lignes, rectangles) et création de dégradés.
# - **Code :** Disponible dans le dossier `TP1/`.
#
# ### TP2 : Histogrammes
#
# - **Statut :** Terminé.
# - **Concepts abordés :** Calcul d'histogramme, égalisation pour améliorer le contraste, Seuillage automatique.
# - **Code :** Disponible dans le dossier `TP2/`.
#
# ### TP3 : Convolution & Filtrage (Séance 3)
#
# - **Statut :** Terminé.
# - **Objectif :** Implémentation manuelle (sans fonction `cv2.filter2D`) des filtres de convolution.
# - **Filtres étudiés :**
#   1.  **Filtre Moyenneur :** Pour lisser l'image et réduire le bruit gaussien.
#   2.  **Filtre Médian :** Pour supprimer le bruit "poivre et sel" (non-linéaire).
#   3.  **Filtre de Sobel (Gradient) :** Pour la détection de contours.
# - **Code :** Disponible dans le dossier `TP3/`.
#
# ### TP4 : opération connexes et segmentation (Séance 4)
#
# - **Statut :** practice mode...
# - **Objectif :**
# - **Filtres étudiés :**
# - **Code :** Disponible dans le dossier `TP4/`.
#
#
# ### TP5 : Morphologie (Séance 5)
#
# - **Statut :** Pas encore commencer!
# - **Objectif :**
# - **Filtres étudiés :**
# - **Code :** Disponible dans le dossier `TP5/`.
#
#
# ### TP6 : Edge and keypoint detectors (Séance 6)
#
# - **Statut :** Pas encore commencer!
# - **Objectif :**
# - **Filtres étudiés :**
# - **Code :** Disponible dans le dossier `TP6/`.
#
# ---
